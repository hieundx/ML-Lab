# %% [markdown]
# # Load data

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score
from catboost import CatBoostClassifier

data = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')

data.head()
# Out:
#    id  CustomerId         Surname  CreditScore Geography Gender   Age  Tenure  \
# 0   0    15674932  Okwudilichukwu          668    France   Male  33.0       3
# 1   1    15749177   Okwudiliolisa          627    France   Male  33.0       1
# 2   2    15694510           Hsueh          678    France   Male  40.0      10
# 3   3    15741417             Kao          581    France   Male  34.0       2
# 4   4    15766172       Chiemenam          716     Spain   Male  33.0       5
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              2        1.0             0.0        181449.97
# 1       0.00              2        1.0             1.0         49503.50
# 2       0.00              2        1.0             0.0        184866.69
# 3  148882.54              1        1.0             1.0         84560.88
# 4       0.00              2        1.0             1.0         15068.83
#
#    Exited
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
print('Training size: ', data.shape[0])
# Out:
# Training size:  165034

# %% [markdown]
# # Data processing

# %% [markdown]
# ## Determine ranges

# %%
print(data['Age'].describe(), end='\n\n')
print(data['EstimatedSalary'].describe(), end='\n\n')
# Out:
# count    165034.000000
# mean         38.125888
# std           8.867205
# min          18.000000
# 25%          32.000000
# 50%          37.000000
# 75%          42.000000
# max          92.000000
# Name: Age, dtype: float64
#
# count    165034.000000
# mean     112574.822734
# std       50292.865585
# min          11.580000
# 25%       74637.570000
# 50%      117948.000000
# 75%      155152.467500
# max      199992.480000
# Name: EstimatedSalary, dtype: float64

# %% [markdown]
# We can see that salary ranges from 11.58 (almost 0) to 199,992.48 (around 200k). First and third quartiles are near multiples of 50k, with median over twice of 50k. So it makes sense to stratefy this column into 0 - 50k, 50k - 100k, 100k - 200k ranges.

# %% [markdown]
# ## Binning

# %%
def cut(data, col, bins):
    data[f'{col}Group'] = pd.cut(data[col], bins=bins, labels=False)

# %% [markdown]
# ## Feature engineering

# %%
def engineer(data):
    # Age groups
    cut(data, 'Age', 5)
    
    # https://www.experian.com/blogs/ask-experian/infographic-what-are-the-different-scoring-ranges/
    cut(data, 'CreditScore', [0, 300, 580, 670, 740, 800, np.inf])
    
    cut(data, 'EstimatedSalary', [0, 50000, 100000, 200000, np.inf])
    
    data['BalanceToSalaryRatio'] = data['Balance'] / data['EstimatedSalary']
    
#     data['TenureGroup'] = pd.cut(data['Tenure'], bins=[0, 2, 5, 10], labels=False)
    
#     data['CreditCard_ActiveMember'] = data['HasCrCard'] * data['IsActiveMember']
    
    return data

# %% [markdown]
# ## Remove outliers
# Outliers can make our model more biased towards such samples. Removing them might increase accuracy on test data.

# %%
def remove_outliers(df):
    quant_cols = [
        'CreditScore',
        'Age', 
        'Balance', 
        'EstimatedSalary'
    ]
    
    for col in quant_cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3-Q1

        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        
        df = df[(df[col] >= lower) & (df[col] <= upper)]
    return df

# %% [markdown]
# ## Label Encoding

# %%
def encode(train, test, cols):
    le = LabelEncoder()
    for col in cols:
        train[col] = le.fit_transform(train[col])
        test[col] = le.fit_transform(test[col])

# %% [markdown]
# ## Combined data processing

# %%
# data = remove_outliers(data)
data = engineer(data)
encode(data, test, ['Geography','Gender'])

test = engineer(test)
encode(data, test, ['Geography','Gender'])

# %% [markdown]
# # Split training data

# %%
from imblearn.over_sampling import SMOTE

drop_cols_test = ['id', 'CustomerId', 'Surname']
drop_cols = drop_cols_test + ['Exited']

x_data = pd.get_dummies(data.drop(drop_cols, axis=1)).astype(np.float32)
y_data = (data['Exited']).astype(np.float32)

scaler = StandardScaler()
x_data = scaler.fit_transform(x_data)

x_data, y_data = SMOTE().fit_resample(x_data, y_data)

# Large data set therefore we just need a small test size for validation purpose
x_train, x_, y_train, y_ = train_test_split(x_data, y_data, test_size=0.2, random_state=0)

# %%
def predict(model, x, y):
    p = model.predict(x)
    p = p.reshape(1, len(p))[0]
    p = np.array(list(map(lambda p: 1 if p >= 0.5 else 0, p)))

    accu = round(accuracy_score(p,  y) , 4)
    
    return accu

def evaluate(model):
    accu_train = predict(model, x_train, y_train)
    accu_dev = predict(model, x_, y_)
    
    print(f'Train: {accu_train}\tDev: {accu_dev}')

    return accu_dev

# %% [markdown]
# # Hyper parameter tuning

# %% [markdown]
# Run this code separately.

# %%
# from sklearn.model_selection import  cross_val_score
# from sklearn.model_selection import StratifiedKFold

# # Assuming 'skf' is your StratifiedKFold object
# skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# def objective_xgb(trial):
#     """Define the objective function for XGBClassifier"""

#     params = {
#         'max_depth': trial.suggest_int('max_depth', 5, 10),
#         'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
#         'learning_rate': trial.suggest_float('learning_rate', 0.01, 1.0),
#         'n_estimators': trial.suggest_int('n_estimators', 150, 1000),
#         'subsample': trial.suggest_float('subsample', 0.01, 1.0),
#         'colsample_bytree': trial.suggest_float('colsample_bytree', 0.01, 1.0),
#         'random_state': trial.suggest_categorical('random_state', [42]),
#         'tree_method': 'hist',  # Use GPU for training
#         'device' : 'cuda',
#         'eval_metric': 'auc',  # Evaluation metric
#         'verbosity': 2,  # Set verbosity to 0 for less output
#     }

#     xgb_model = XGBRegressor(**params)

#     cv = abs(cross_val_score(xgb_model, x_train, y_train, cv=skf, scoring='roc_auc').mean())

#     return cv

# study = optuna.create_study(direction='maximize')
# study.optimize(objective_xgb, n_trials=50)

# # Get the best parameters
# best_params_xgb = study.best_params
# print("Best Hyperparameters for XGBoost:", best_params_xgb)

# %% [markdown]
# Best Hyperparameters found using Optuna
# ```
# {
#     'max_depth': 6,
#     'min_child_weight': 6,
#     'learning_rate': 0.015456088221076969,
#     'n_estimators': 535,
#     'subsample': 0.25556380739804013,
#     'colsample_bytree': 0.6705216911932783,
#     'random_state': 42
# }
# ```

# %%
from sklearn.model_selection import  cross_val_score
from sklearn.model_selection import StratifiedKFold
import optuna
from catboost import CatBoostClassifier

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

def objective_cb(trial):
    params = {
        'depth': trial.suggest_int('depth', 5, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
        'iterations': trial.suggest_int('iterations', 100, 500),
        'verbose': False,
        'l2_leaf_reg': trial.suggest_int('l2_leaf_reg', 0.2, 2),
        'task_type':"GPU",  # Use GPU for training
        'devices' : '0:1',
        # 'eval_metric': 'AUC',  # Evaluation metric
    }

    cb_model = CatBoostClassifier(**params)

    cv = abs(cross_val_score(cb_model, x_train, y_train, cv=skf, scoring='roc_auc').mean())

    return cv

study = optuna.create_study(direction='maximize')
study.optimize(objective_cb, n_trials=5)

# Get the best parameters
best_params_cb = study.best_params
print("Hyperparameters found:", best_params_cb)
# Out:
# [I 2024-01-14 16:57:53,941] A new study created in memory with name: no-name-e797883b-738f-48a9-921b-d8fe8d544743
# [I 2024-01-14 16:58:48,195] Trial 0 finished with value: 0.9662344526372907 and parameters: {'depth': 9, 'learning_rate': 0.028886480232587365, 'iterations': 400, 'l2_leaf_reg': 1}. Best is trial 0 with value: 0.9662344526372907.
# [I 2024-01-14 16:59:01,366] Trial 1 finished with value: 0.9616263735144968 and parameters: {'depth': 8, 'learning_rate': 0.07826093696342286, 'iterations': 174, 'l2_leaf_reg': 1}. Best is trial 0 with value: 0.9662344526372907.
# [I 2024-01-14 17:00:07,405] Trial 2 finished with value: 0.9661093367899088 and parameters: {'depth': 9, 'learning_rate': 0.023064545609397948, 'iterations': 486, 'l2_leaf_reg': 1}. Best is trial 0 with value: 0.9662344526372907.
# [I 2024-01-14 17:00:52,126] Trial 3 finished with value: 0.9672109136365223 and parameters: {'depth': 9, 'learning_rate': 0.0519263317978695, 'iterations': 325, 'l2_leaf_reg': 1}. Best is trial 3 with value: 0.9672109136365223.
# [I 2024-01-14 17:01:18,909] Trial 4 finished with value: 0.9654156870160353 and parameters: {'depth': 5, 'learning_rate': 0.03232647820277573, 'iterations': 402, 'l2_leaf_reg': 0}. Best is trial 3 with value: 0.9672109136365223.
# Hyperparameters found: {'depth': 9, 'learning_rate': 0.0519263317978695, 'iterations': 325, 'l2_leaf_reg': 1}

# %% [markdown]
# # Train

# %%
from xgboost import XGBRegressor

params_xgb = {
    'max_depth': 6, 
    'min_child_weight': 6, 
    'learning_rate': 0.015456088221076969, 
    'n_estimators': 535, 
    'subsample': 0.25556380739804013, 
    'colsample_bytree': 0.6705216911932783, 
    'random_state': 42
}

# Params found using Optuna
model_xgb = XGBRegressor(**params_xgb)
model_xgb.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.6705216911932783, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.015456088221076969, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=6, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=535, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
params_cb = {'depth': 7, 'learning_rate': 0.054768705429762574, 'iterations': 467, 'l2_leaf_reg': 1}

model_cb = CatBoostClassifier(**params_cb)
model_cb.fit(x_train, y_train)
# Out:
# 0:	learn: 0.6579096	total: 43.1ms	remaining: 20.1s
# 1:	learn: 0.6271947	total: 81.4ms	remaining: 18.9s
# 2:	learn: 0.6008972	total: 119ms	remaining: 18.4s
# 3:	learn: 0.5783039	total: 157ms	remaining: 18.2s
# 4:	learn: 0.5582040	total: 192ms	remaining: 17.8s
# 5:	learn: 0.5407940	total: 225ms	remaining: 17.3s
# 6:	learn: 0.5241579	total: 259ms	remaining: 17s
# 7:	learn: 0.5111016	total: 309ms	remaining: 17.8s
# 8:	learn: 0.4983988	total: 360ms	remaining: 18.3s
# 9:	learn: 0.4877390	total: 401ms	remaining: 18.3s
# 10:	learn: 0.4778097	total: 449ms	remaining: 18.6s
# 11:	learn: 0.4687140	total: 487ms	remaining: 18.5s
# 12:	learn: 0.4617282	total: 524ms	remaining: 18.3s
# 13:	learn: 0.4546214	total: 560ms	remaining: 18.1s
# 14:	learn: 0.4483422	total: 592ms	remaining: 17.8s
# 15:	learn: 0.4431614	total: 636ms	remaining: 17.9s
# 16:	learn: 0.4373532	total: 676ms	remaining: 17.9s
# 17:	learn: 0.4322498	total: 716ms	remaining: 17.9s
# 18:	learn: 0.4267109	total: 758ms	remaining: 17.9s
# 19:	learn: 0.4217703	total: 783ms	remaining: 17.5s
# 20:	learn: 0.4180947	total: 809ms	remaining: 17.2s
# 21:	learn: 0.4127177	total: 840ms	remaining: 17s
# 22:	learn: 0.4078393	total: 869ms	remaining: 16.8s
# 23:	learn: 0.4046438	total: 897ms	remaining: 16.6s
# 24:	learn: 0.4019856	total: 928ms	remaining: 16.4s
# 25:	learn: 0.4001037	total: 965ms	remaining: 16.4s
# 26:	learn: 0.3973639	total: 994ms	remaining: 16.2s
# 27:	learn: 0.3939023	total: 1.02s	remaining: 16s
# 28:	learn: 0.3877326	total: 1.05s	remaining: 15.9s
# 29:	learn: 0.3814565	total: 1.08s	remaining: 15.7s
# 30:	learn: 0.3727440	total: 1.11s	remaining: 15.6s
# 31:	learn: 0.3661216	total: 1.16s	remaining: 15.8s
# 32:	learn: 0.3630654	total: 1.2s	remaining: 15.8s
# 33:	learn: 0.3604467	total: 1.23s	remaining: 15.6s
# 34:	learn: 0.3589396	total: 1.27s	remaining: 15.6s
# 35:	learn: 0.3572872	total: 1.31s	remaining: 15.7s
# 36:	learn: 0.3557798	total: 1.34s	remaining: 15.6s
# 37:	learn: 0.3541982	total: 1.38s	remaining: 15.6s
# 38:	learn: 0.3525660	total: 1.41s	remaining: 15.5s
# 39:	learn: 0.3495657	total: 1.44s	remaining: 15.4s
# 40:	learn: 0.3476014	total: 1.47s	remaining: 15.3s
# 41:	learn: 0.3456862	total: 1.5s	remaining: 15.2s
# 42:	learn: 0.3446277	total: 1.53s	remaining: 15.1s
# 43:	learn: 0.3425538	total: 1.56s	remaining: 15s
# 44:	learn: 0.3418690	total: 1.59s	remaining: 15s
# 45:	learn: 0.3404720	total: 1.63s	remaining: 15s
# 46:	learn: 0.3396204	total: 1.67s	remaining: 14.9s
# 47:	learn: 0.3375434	total: 1.71s	remaining: 14.9s
# 48:	learn: 0.3330078	total: 1.74s	remaining: 14.9s
# 49:	learn: 0.3279801	total: 1.77s	remaining: 14.8s
# 50:	learn: 0.3274700	total: 1.81s	remaining: 14.7s
# 51:	learn: 0.3264362	total: 1.84s	remaining: 14.7s
# 52:	learn: 0.3251579	total: 1.87s	remaining: 14.6s
# 53:	learn: 0.3237283	total: 1.9s	remaining: 14.6s
# 54:	learn: 0.3231734	total: 1.93s	remaining: 14.5s
# 55:	learn: 0.3225293	total: 1.96s	remaining: 14.4s
# 56:	learn: 0.3207348	total: 1.99s	remaining: 14.3s
# 57:	learn: 0.3203368	total: 2.02s	remaining: 14.2s
# 58:	learn: 0.3196924	total: 2.06s	remaining: 14.3s
# 59:	learn: 0.3179080	total: 2.1s	remaining: 14.2s
# 60:	learn: 0.3157445	total: 2.13s	remaining: 14.2s
# 61:	learn: 0.3140570	total: 2.17s	remaining: 14.2s
# 62:	learn: 0.3136793	total: 2.2s	remaining: 14.1s
# 63:	learn: 0.3118109	total: 2.24s	remaining: 14.1s
# 64:	learn: 0.3087869	total: 2.28s	remaining: 14.1s
# 65:	learn: 0.3077144	total: 2.32s	remaining: 14.1s
# 66:	learn: 0.3071881	total: 2.36s	remaining: 14.1s
# 67:	learn: 0.3048397	total: 2.4s	remaining: 14.1s
# 68:	learn: 0.3036665	total: 2.43s	remaining: 14s
# 69:	learn: 0.3031558	total: 2.47s	remaining: 14s
# 70:	learn: 0.3016632	total: 2.5s	remaining: 14s
# 71:	learn: 0.3014265	total: 2.54s	remaining: 13.9s
# 72:	learn: 0.2975556	total: 2.58s	remaining: 13.9s
# 73:	learn: 0.2959330	total: 2.61s	remaining: 13.9s
# 74:	learn: 0.2930117	total: 2.65s	remaining: 13.9s
# 75:	learn: 0.2927864	total: 2.7s	remaining: 13.9s
# 76:	learn: 0.2925021	total: 2.75s	remaining: 13.9s
# 77:	learn: 0.2921779	total: 2.78s	remaining: 13.9s
# 78:	learn: 0.2895023	total: 2.81s	remaining: 13.8s
# 79:	learn: 0.2874854	total: 2.84s	remaining: 13.7s
# 80:	learn: 0.2872684	total: 2.87s	remaining: 13.7s
# 81:	learn: 0.2858356	total: 2.91s	remaining: 13.7s
# 82:	learn: 0.2856123	total: 2.94s	remaining: 13.6s
# 83:	learn: 0.2840548	total: 2.98s	remaining: 13.6s
# 84:	learn: 0.2817398	total: 3.02s	remaining: 13.6s
# 85:	learn: 0.2813787	total: 3.07s	remaining: 13.6s
# 86:	learn: 0.2810113	total: 3.12s	remaining: 13.6s
# 87:	learn: 0.2801840	total: 3.16s	remaining: 13.6s
# 88:	learn: 0.2799099	total: 3.19s	remaining: 13.6s
# 89:	learn: 0.2797467	total: 3.23s	remaining: 13.5s
# 90:	learn: 0.2795716	total: 3.26s	remaining: 13.5s
# 91:	learn: 0.2792512	total: 3.3s	remaining: 13.4s
# 92:	learn: 0.2785611	total: 3.34s	remaining: 13.4s
# 93:	learn: 0.2776530	total: 3.38s	remaining: 13.4s
# 94:	learn: 0.2774717	total: 3.4s	remaining: 13.3s
# 95:	learn: 0.2768337	total: 3.44s	remaining: 13.3s
# 96:	learn: 0.2762224	total: 3.47s	remaining: 13.2s
# 97:	learn: 0.2743698	total: 3.5s	remaining: 13.2s
# 98:	learn: 0.2731385	total: 3.54s	remaining: 13.1s
# 99:	learn: 0.2726975	total: 3.57s	remaining: 13.1s
# 100:	learn: 0.2725073	total: 3.6s	remaining: 13.1s
# 101:	learn: 0.2720911	total: 3.64s	remaining: 13s
# 102:	learn: 0.2719354	total: 3.67s	remaining: 13s
# 103:	learn: 0.2714708	total: 3.71s	remaining: 12.9s
# 104:	learn: 0.2713707	total: 3.75s	remaining: 12.9s
# 105:	learn: 0.2703005	total: 3.79s	remaining: 12.9s
# 106:	learn: 0.2695308	total: 3.82s	remaining: 12.9s
# 107:	learn: 0.2693045	total: 3.85s	remaining: 12.8s
# 108:	learn: 0.2687370	total: 3.89s	remaining: 12.8s
# 109:	learn: 0.2676188	total: 3.92s	remaining: 12.7s
# 110:	learn: 0.2671411	total: 3.95s	remaining: 12.7s
# 111:	learn: 0.2662098	total: 3.99s	remaining: 12.6s
# 112:	learn: 0.2661101	total: 4.03s	remaining: 12.6s
# 113:	learn: 0.2657487	total: 4.06s	remaining: 12.6s
# 114:	learn: 0.2653003	total: 4.09s	remaining: 12.5s
# 115:	learn: 0.2652107	total: 4.12s	remaining: 12.5s
# 116:	learn: 0.2651210	total: 4.15s	remaining: 12.4s
# 117:	learn: 0.2648236	total: 4.18s	remaining: 12.4s
# 118:	learn: 0.2645148	total: 4.21s	remaining: 12.3s
# 119:	learn: 0.2633678	total: 4.25s	remaining: 12.3s
# 120:	learn: 0.2627166	total: 4.28s	remaining: 12.3s
# 121:	learn: 0.2619431	total: 4.33s	remaining: 12.2s
# 122:	learn: 0.2616916	total: 4.37s	remaining: 12.2s
# 123:	learn: 0.2612429	total: 4.41s	remaining: 12.2s
# 124:	learn: 0.2607979	total: 4.43s	remaining: 12.1s
# 125:	learn: 0.2606831	total: 4.46s	remaining: 12.1s
# 126:	learn: 0.2598346	total: 4.48s	remaining: 12s
# 127:	learn: 0.2592889	total: 4.51s	remaining: 12s
# 128:	learn: 0.2590197	total: 4.54s	remaining: 11.9s
# 129:	learn: 0.2585749	total: 4.58s	remaining: 11.9s
# 130:	learn: 0.2585113	total: 4.61s	remaining: 11.8s
# 131:	learn: 0.2582251	total: 4.64s	remaining: 11.8s
# 132:	learn: 0.2581367	total: 4.67s	remaining: 11.7s
# 133:	learn: 0.2580494	total: 4.7s	remaining: 11.7s
# 134:	learn: 0.2579942	total: 4.72s	remaining: 11.6s
# 135:	learn: 0.2576090	total: 4.75s	remaining: 11.6s
# 136:	learn: 0.2574450	total: 4.79s	remaining: 11.5s
# 137:	learn: 0.2573428	total: 4.82s	remaining: 11.5s
# 138:	learn: 0.2567624	total: 4.85s	remaining: 11.4s
# 139:	learn: 0.2564910	total: 4.88s	remaining: 11.4s
# 140:	learn: 0.2557530	total: 4.91s	remaining: 11.4s
# 141:	learn: 0.2556795	total: 4.94s	remaining: 11.3s
# 142:	learn: 0.2554125	total: 4.97s	remaining: 11.3s
# 143:	learn: 0.2553092	total: 5s	remaining: 11.2s
# 144:	learn: 0.2545590	total: 5.04s	remaining: 11.2s
# 145:	learn: 0.2543320	total: 5.07s	remaining: 11.1s
# 146:	learn: 0.2531821	total: 5.1s	remaining: 11.1s
# 147:	learn: 0.2529022	total: 5.13s	remaining: 11.1s
# 148:	learn: 0.2528331	total: 5.16s	remaining: 11s
# 149:	learn: 0.2527263	total: 5.19s	remaining: 11s
# 150:	learn: 0.2520016	total: 5.23s	remaining: 10.9s
# 151:	learn: 0.2518187	total: 5.28s	remaining: 10.9s
# 152:	learn: 0.2517343	total: 5.32s	remaining: 10.9s
# 153:	learn: 0.2514143	total: 5.36s	remaining: 10.9s
# 154:	learn: 0.2513522	total: 5.39s	remaining: 10.9s
# 155:	learn: 0.2512710	total: 5.43s	remaining: 10.8s
# 156:	learn: 0.2510641	total: 5.46s	remaining: 10.8s
# 157:	learn: 0.2509292	total: 5.49s	remaining: 10.7s
# 158:	learn: 0.2506612	total: 5.52s	remaining: 10.7s
# 159:	learn: 0.2505892	total: 5.55s	remaining: 10.6s
# 160:	learn: 0.2505372	total: 5.58s	remaining: 10.6s
# 161:	learn: 0.2503365	total: 5.61s	remaining: 10.6s
# 162:	learn: 0.2502662	total: 5.64s	remaining: 10.5s
# 163:	learn: 0.2501489	total: 5.67s	remaining: 10.5s
# 164:	learn: 0.2496970	total: 5.69s	remaining: 10.4s
# 165:	learn: 0.2496222	total: 5.72s	remaining: 10.4s
# 166:	learn: 0.2495322	total: 5.75s	remaining: 10.3s
# 167:	learn: 0.2494739	total: 5.77s	remaining: 10.3s
# 168:	learn: 0.2494276	total: 5.8s	remaining: 10.2s
# 169:	learn: 0.2492795	total: 5.83s	remaining: 10.2s
# 170:	learn: 0.2492275	total: 5.85s	remaining: 10.1s
# 171:	learn: 0.2491226	total: 5.88s	remaining: 10.1s
# 172:	learn: 0.2486332	total: 5.91s	remaining: 10s
# 173:	learn: 0.2484258	total: 5.94s	remaining: 10s
# 174:	learn: 0.2483754	total: 5.97s	remaining: 9.96s
# 175:	learn: 0.2483349	total: 5.99s	remaining: 9.91s
# 176:	learn: 0.2481163	total: 6.02s	remaining: 9.86s
# 177:	learn: 0.2477998	total: 6.05s	remaining: 9.83s
# 178:	learn: 0.2477455	total: 6.09s	remaining: 9.8s
# 179:	learn: 0.2475228	total: 6.13s	remaining: 9.78s
# 180:	learn: 0.2473594	total: 6.18s	remaining: 9.76s
# 181:	learn: 0.2467420	total: 6.22s	remaining: 9.73s
# 182:	learn: 0.2463017	total: 6.26s	remaining: 9.71s
# 183:	learn: 0.2461649	total: 6.31s	remaining: 9.7s
# 184:	learn: 0.2451632	total: 6.34s	remaining: 9.67s
# 185:	learn: 0.2450950	total: 6.38s	remaining: 9.65s
# 186:	learn: 0.2449864	total: 6.42s	remaining: 9.62s
# 187:	learn: 0.2439413	total: 6.46s	remaining: 9.58s
# 188:	learn: 0.2436794	total: 6.49s	remaining: 9.55s
# 189:	learn: 0.2435853	total: 6.52s	remaining: 9.51s
# 190:	learn: 0.2434524	total: 6.56s	remaining: 9.48s
# 191:	learn: 0.2428131	total: 6.6s	remaining: 9.46s
# 192:	learn: 0.2427491	total: 6.64s	remaining: 9.43s
# 193:	learn: 0.2426848	total: 6.67s	remaining: 9.38s
# 194:	learn: 0.2425280	total: 6.7s	remaining: 9.34s
# 195:	learn: 0.2421979	total: 6.72s	remaining: 9.3s
# 196:	learn: 0.2419043	total: 6.75s	remaining: 9.26s
# 197:	learn: 0.2417977	total: 6.78s	remaining: 9.21s
# 198:	learn: 0.2417589	total: 6.81s	remaining: 9.17s
# 199:	learn: 0.2413822	total: 6.85s	remaining: 9.14s
# 200:	learn: 0.2410007	total: 6.87s	remaining: 9.1s
# 201:	learn: 0.2409645	total: 6.91s	remaining: 9.06s
# 202:	learn: 0.2406200	total: 6.93s	remaining: 9.02s
# 203:	learn: 0.2404468	total: 6.96s	remaining: 8.98s
# 204:	learn: 0.2403845	total: 6.99s	remaining: 8.93s
# 205:	learn: 0.2400605	total: 7.02s	remaining: 8.89s
# 206:	learn: 0.2398262	total: 7.05s	remaining: 8.86s
# 207:	learn: 0.2395393	total: 7.09s	remaining: 8.82s
# 208:	learn: 0.2392489	total: 7.12s	remaining: 8.78s
# 209:	learn: 0.2386529	total: 7.14s	remaining: 8.74s
# 210:	learn: 0.2384672	total: 7.17s	remaining: 8.7s
# 211:	learn: 0.2384252	total: 7.2s	remaining: 8.66s
# 212:	learn: 0.2382398	total: 7.23s	remaining: 8.63s
# 213:	learn: 0.2380526	total: 7.26s	remaining: 8.58s
# 214:	learn: 0.2380085	total: 7.29s	remaining: 8.55s
# 215:	learn: 0.2379172	total: 7.32s	remaining: 8.51s
# 216:	learn: 0.2378764	total: 7.36s	remaining: 8.48s
# 217:	learn: 0.2378311	total: 7.4s	remaining: 8.45s
# 218:	learn: 0.2377182	total: 7.43s	remaining: 8.41s
# 219:	learn: 0.2375513	total: 7.46s	remaining: 8.37s
# 220:	learn: 0.2375015	total: 7.48s	remaining: 8.33s
# 221:	learn: 0.2372803	total: 7.51s	remaining: 8.29s
# 222:	learn: 0.2372243	total: 7.54s	remaining: 8.25s
# 223:	learn: 0.2368335	total: 7.57s	remaining: 8.21s
# 224:	learn: 0.2365268	total: 7.6s	remaining: 8.18s
# 225:	learn: 0.2361482	total: 7.64s	remaining: 8.15s
# 226:	learn: 0.2353685	total: 7.68s	remaining: 8.12s
# 227:	learn: 0.2352992	total: 7.71s	remaining: 8.08s
# 228:	learn: 0.2346815	total: 7.75s	remaining: 8.05s
# 229:	learn: 0.2345258	total: 7.78s	remaining: 8.01s
# 230:	learn: 0.2343986	total: 7.81s	remaining: 7.98s
# 231:	learn: 0.2342585	total: 7.84s	remaining: 7.94s
# 232:	learn: 0.2340878	total: 7.87s	remaining: 7.9s
# 233:	learn: 0.2340288	total: 7.89s	remaining: 7.86s
# 234:	learn: 0.2335786	total: 7.92s	remaining: 7.82s
# 235:	learn: 0.2331510	total: 7.96s	remaining: 7.79s
# 236:	learn: 0.2330263	total: 7.99s	remaining: 7.76s
# 237:	learn: 0.2329703	total: 8.04s	remaining: 7.74s
# 238:	learn: 0.2329197	total: 8.07s	remaining: 7.7s
# 239:	learn: 0.2327530	total: 8.09s	remaining: 7.66s
# 240:	learn: 0.2326322	total: 8.12s	remaining: 7.62s
# 241:	learn: 0.2325617	total: 8.15s	remaining: 7.58s
# 242:	learn: 0.2321404	total: 8.19s	remaining: 7.54s
# 243:	learn: 0.2318791	total: 8.21s	remaining: 7.5s
# 244:	learn: 0.2317026	total: 8.25s	remaining: 7.47s
# 245:	learn: 0.2314717	total: 8.28s	remaining: 7.44s
# 246:	learn: 0.2314327	total: 8.31s	remaining: 7.41s
# 247:	learn: 0.2313583	total: 8.34s	remaining: 7.37s
# 248:	learn: 0.2312265	total: 8.38s	remaining: 7.33s
# 249:	learn: 0.2310773	total: 8.41s	remaining: 7.3s
# 250:	learn: 0.2310253	total: 8.44s	remaining: 7.26s
# 251:	learn: 0.2304918	total: 8.47s	remaining: 7.23s
# 252:	learn: 0.2303286	total: 8.51s	remaining: 7.2s
# 253:	learn: 0.2301891	total: 8.54s	remaining: 7.17s
# 254:	learn: 0.2300988	total: 8.59s	remaining: 7.14s
# 255:	learn: 0.2300580	total: 8.62s	remaining: 7.1s
# 256:	learn: 0.2300188	total: 8.64s	remaining: 7.06s
# 257:	learn: 0.2298974	total: 8.67s	remaining: 7.02s
# 258:	learn: 0.2297066	total: 8.71s	remaining: 6.99s
# 259:	learn: 0.2295993	total: 8.74s	remaining: 6.96s
# 260:	learn: 0.2295618	total: 8.77s	remaining: 6.92s
# 261:	learn: 0.2295094	total: 8.8s	remaining: 6.88s
# 262:	learn: 0.2294771	total: 8.83s	remaining: 6.85s
# 263:	learn: 0.2294110	total: 8.86s	remaining: 6.81s
# 264:	learn: 0.2289139	total: 8.88s	remaining: 6.77s
# 265:	learn: 0.2285697	total: 8.92s	remaining: 6.74s
# 266:	learn: 0.2283013	total: 8.95s	remaining: 6.71s
# 267:	learn: 0.2281843	total: 8.99s	remaining: 6.67s
# 268:	learn: 0.2281138	total: 9.02s	remaining: 6.63s
# 269:	learn: 0.2277790	total: 9.04s	remaining: 6.6s
# 270:	learn: 0.2276542	total: 9.09s	remaining: 6.57s
# 271:	learn: 0.2272590	total: 9.14s	remaining: 6.55s
# 272:	learn: 0.2271632	total: 9.16s	remaining: 6.51s
# 273:	learn: 0.2271218	total: 9.2s	remaining: 6.48s
# 274:	learn: 0.2270801	total: 9.22s	remaining: 6.44s
# 275:	learn: 0.2270319	total: 9.27s	remaining: 6.41s
# 276:	learn: 0.2269871	total: 9.3s	remaining: 6.38s
# 277:	learn: 0.2268149	total: 9.34s	remaining: 6.35s
# 278:	learn: 0.2266740	total: 9.37s	remaining: 6.32s
# 279:	learn: 0.2266031	total: 9.4s	remaining: 6.28s
# 280:	learn: 0.2264615	total: 9.44s	remaining: 6.25s
# 281:	learn: 0.2262449	total: 9.47s	remaining: 6.21s
# 282:	learn: 0.2259015	total: 9.51s	remaining: 6.18s
# 283:	learn: 0.2258586	total: 9.55s	remaining: 6.15s
# 284:	learn: 0.2258202	total: 9.58s	remaining: 6.12s
# 285:	learn: 0.2257257	total: 9.61s	remaining: 6.08s
# 286:	learn: 0.2256495	total: 9.65s	remaining: 6.05s
# 287:	learn: 0.2256042	total: 9.7s	remaining: 6.03s
# 288:	learn: 0.2255586	total: 9.75s	remaining: 6.01s
# 289:	learn: 0.2253811	total: 9.8s	remaining: 5.98s
# 290:	learn: 0.2252894	total: 9.85s	remaining: 5.96s
# 291:	learn: 0.2252571	total: 9.9s	remaining: 5.93s
# 292:	learn: 0.2250191	total: 9.94s	remaining: 5.9s
# 293:	learn: 0.2249842	total: 9.97s	remaining: 5.87s
# 294:	learn: 0.2248622	total: 10s	remaining: 5.84s
# 295:	learn: 0.2248252	total: 10.1s	remaining: 5.81s
# 296:	learn: 0.2247884	total: 10.1s	remaining: 5.81s
# 297:	learn: 0.2247457	total: 10.2s	remaining: 5.8s
# 298:	learn: 0.2244483	total: 10.3s	remaining: 5.78s
# 299:	learn: 0.2244183	total: 10.3s	remaining: 5.74s
# 300:	learn: 0.2243791	total: 10.3s	remaining: 5.7s
# 301:	learn: 0.2243423	total: 10.4s	remaining: 5.67s
# 302:	learn: 0.2242916	total: 10.4s	remaining: 5.63s
# 303:	learn: 0.2239967	total: 10.4s	remaining: 5.59s
# 304:	learn: 0.2239394	total: 10.5s	remaining: 5.56s
# 305:	learn: 0.2239029	total: 10.5s	remaining: 5.52s
# 306:	learn: 0.2237967	total: 10.5s	remaining: 5.49s
# 307:	learn: 0.2236928	total: 10.6s	remaining: 5.46s
# 308:	learn: 0.2235554	total: 10.6s	remaining: 5.43s
# 309:	learn: 0.2234996	total: 10.7s	remaining: 5.39s
# 310:	learn: 0.2234518	total: 10.7s	remaining: 5.36s
# 311:	learn: 0.2233131	total: 10.7s	remaining: 5.32s
# 312:	learn: 0.2230641	total: 10.7s	remaining: 5.29s
# 313:	learn: 0.2230271	total: 10.8s	remaining: 5.25s
# 314:	learn: 0.2229873	total: 10.8s	remaining: 5.22s
# 315:	learn: 0.2229100	total: 10.8s	remaining: 5.18s
# 316:	learn: 0.2228704	total: 10.9s	remaining: 5.14s
# 317:	learn: 0.2228372	total: 10.9s	remaining: 5.11s
# 318:	learn: 0.2227714	total: 10.9s	remaining: 5.08s
# 319:	learn: 0.2227421	total: 11s	remaining: 5.04s
# 320:	learn: 0.2226920	total: 11s	remaining: 5s
# 321:	learn: 0.2226625	total: 11s	remaining: 4.96s
# 322:	learn: 0.2226194	total: 11.1s	remaining: 4.93s
# 323:	learn: 0.2225777	total: 11.1s	remaining: 4.89s
# 324:	learn: 0.2225480	total: 11.1s	remaining: 4.86s
# 325:	learn: 0.2225145	total: 11.2s	remaining: 4.83s
# 326:	learn: 0.2224823	total: 11.2s	remaining: 4.79s
# 327:	learn: 0.2224056	total: 11.2s	remaining: 4.75s
# 328:	learn: 0.2223685	total: 11.3s	remaining: 4.72s
# 329:	learn: 0.2222689	total: 11.3s	remaining: 4.68s
# 330:	learn: 0.2221395	total: 11.3s	remaining: 4.64s
# 331:	learn: 0.2220036	total: 11.3s	remaining: 4.61s
# 332:	learn: 0.2218965	total: 11.4s	remaining: 4.57s
# 333:	learn: 0.2218094	total: 11.4s	remaining: 4.53s
# 334:	learn: 0.2217673	total: 11.4s	remaining: 4.5s
# 335:	learn: 0.2216954	total: 11.4s	remaining: 4.46s
# 336:	learn: 0.2216039	total: 11.5s	remaining: 4.42s
# 337:	learn: 0.2215666	total: 11.5s	remaining: 4.39s
# 338:	learn: 0.2215095	total: 11.5s	remaining: 4.35s
# 339:	learn: 0.2214705	total: 11.6s	remaining: 4.32s
# 340:	learn: 0.2214322	total: 11.6s	remaining: 4.29s
# 341:	learn: 0.2213976	total: 11.6s	remaining: 4.26s
# 342:	learn: 0.2213433	total: 11.7s	remaining: 4.22s
# 343:	learn: 0.2212201	total: 11.7s	remaining: 4.18s
# 344:	learn: 0.2211821	total: 11.7s	remaining: 4.15s
# 345:	learn: 0.2211437	total: 11.8s	remaining: 4.12s
# 346:	learn: 0.2211097	total: 11.8s	remaining: 4.08s
# 347:	learn: 0.2210709	total: 11.8s	remaining: 4.05s
# 348:	learn: 0.2209949	total: 11.9s	remaining: 4.01s
# 349:	learn: 0.2209650	total: 11.9s	remaining: 3.98s
# 350:	learn: 0.2209316	total: 11.9s	remaining: 3.94s
# 351:	learn: 0.2208872	total: 12s	remaining: 3.91s
# 352:	learn: 0.2207954	total: 12s	remaining: 3.87s
# 353:	learn: 0.2207558	total: 12s	remaining: 3.84s
# 354:	learn: 0.2207221	total: 12.1s	remaining: 3.8s
# 355:	learn: 0.2206437	total: 12.1s	remaining: 3.77s
# 356:	learn: 0.2206145	total: 12.1s	remaining: 3.73s
# 357:	learn: 0.2205909	total: 12.1s	remaining: 3.7s
# 358:	learn: 0.2205555	total: 12.2s	remaining: 3.66s
# 359:	learn: 0.2205079	total: 12.2s	remaining: 3.63s
# 360:	learn: 0.2204799	total: 12.2s	remaining: 3.6s
# 361:	learn: 0.2204543	total: 12.3s	remaining: 3.56s
# 362:	learn: 0.2204213	total: 12.3s	remaining: 3.53s
# 363:	learn: 0.2203984	total: 12.3s	remaining: 3.49s
# 364:	learn: 0.2203653	total: 12.4s	remaining: 3.46s
# 365:	learn: 0.2203361	total: 12.4s	remaining: 3.42s
# 366:	learn: 0.2202986	total: 12.4s	remaining: 3.39s
# 367:	learn: 0.2202601	total: 12.5s	remaining: 3.35s
# 368:	learn: 0.2202303	total: 12.5s	remaining: 3.31s
# 369:	learn: 0.2202100	total: 12.5s	remaining: 3.28s
# 370:	learn: 0.2201789	total: 12.5s	remaining: 3.25s
# 371:	learn: 0.2200928	total: 12.6s	remaining: 3.21s
# 372:	learn: 0.2200564	total: 12.6s	remaining: 3.18s
# 373:	learn: 0.2199549	total: 12.6s	remaining: 3.15s
# 374:	learn: 0.2199310	total: 12.7s	remaining: 3.11s
# 375:	learn: 0.2198983	total: 12.7s	remaining: 3.07s
# 376:	learn: 0.2198222	total: 12.7s	remaining: 3.04s
# 377:	learn: 0.2197921	total: 12.8s	remaining: 3s
# 378:	learn: 0.2197627	total: 12.8s	remaining: 2.97s
# 379:	learn: 0.2197435	total: 12.8s	remaining: 2.93s
# 380:	learn: 0.2196561	total: 12.8s	remaining: 2.9s
# 381:	learn: 0.2196251	total: 12.9s	remaining: 2.86s
# 382:	learn: 0.2195934	total: 12.9s	remaining: 2.83s
# 383:	learn: 0.2195677	total: 12.9s	remaining: 2.79s
# 384:	learn: 0.2194828	total: 12.9s	remaining: 2.76s
# 385:	learn: 0.2194594	total: 13s	remaining: 2.72s
# 386:	learn: 0.2194157	total: 13s	remaining: 2.69s
# 387:	learn: 0.2193863	total: 13s	remaining: 2.65s
# 388:	learn: 0.2192632	total: 13s	remaining: 2.62s
# 389:	learn: 0.2192277	total: 13.1s	remaining: 2.58s
# 390:	learn: 0.2192055	total: 13.1s	remaining: 2.55s
# 391:	learn: 0.2191721	total: 13.1s	remaining: 2.51s
# 392:	learn: 0.2191424	total: 13.2s	remaining: 2.48s
# 393:	learn: 0.2191195	total: 13.2s	remaining: 2.44s
# 394:	learn: 0.2190934	total: 13.2s	remaining: 2.41s
# 395:	learn: 0.2190678	total: 13.3s	remaining: 2.38s
# 396:	learn: 0.2190361	total: 13.3s	remaining: 2.35s
# 397:	learn: 0.2189995	total: 13.3s	remaining: 2.31s
# 398:	learn: 0.2189769	total: 13.4s	remaining: 2.28s
# 399:	learn: 0.2189532	total: 13.4s	remaining: 2.24s
# 400:	learn: 0.2189340	total: 13.4s	remaining: 2.21s
# 401:	learn: 0.2188792	total: 13.5s	remaining: 2.18s
# 402:	learn: 0.2188540	total: 13.5s	remaining: 2.14s
# 403:	learn: 0.2188222	total: 13.5s	remaining: 2.11s
# 404:	learn: 0.2187913	total: 13.6s	remaining: 2.08s
# 405:	learn: 0.2187667	total: 13.6s	remaining: 2.05s
# 406:	learn: 0.2187342	total: 13.7s	remaining: 2.02s
# 407:	learn: 0.2187017	total: 13.7s	remaining: 1.98s
# 408:	learn: 0.2186495	total: 13.7s	remaining: 1.95s
# 409:	learn: 0.2186152	total: 13.8s	remaining: 1.92s
# 410:	learn: 0.2185895	total: 13.8s	remaining: 1.88s
# 411:	learn: 0.2185692	total: 13.9s	remaining: 1.85s
# 412:	learn: 0.2185445	total: 13.9s	remaining: 1.82s
# 413:	learn: 0.2185071	total: 13.9s	remaining: 1.78s
# 414:	learn: 0.2183957	total: 14s	remaining: 1.75s
# 415:	learn: 0.2183716	total: 14s	remaining: 1.72s
# 416:	learn: 0.2182939	total: 14.1s	remaining: 1.69s
# 417:	learn: 0.2182661	total: 14.1s	remaining: 1.65s
# 418:	learn: 0.2182339	total: 14.1s	remaining: 1.62s
# 419:	learn: 0.2182022	total: 14.2s	remaining: 1.58s
# 420:	learn: 0.2181718	total: 14.2s	remaining: 1.55s
# 421:	learn: 0.2180856	total: 14.2s	remaining: 1.52s
# 422:	learn: 0.2180611	total: 14.3s	remaining: 1.49s
# 423:	learn: 0.2180117	total: 14.3s	remaining: 1.45s
# 424:	learn: 0.2179870	total: 14.4s	remaining: 1.42s
# 425:	learn: 0.2179645	total: 14.4s	remaining: 1.39s
# 426:	learn: 0.2178860	total: 14.4s	remaining: 1.35s
# 427:	learn: 0.2177933	total: 14.5s	remaining: 1.32s
# 428:	learn: 0.2177577	total: 14.5s	remaining: 1.28s
# 429:	learn: 0.2177335	total: 14.6s	remaining: 1.25s
# 430:	learn: 0.2176220	total: 14.6s	remaining: 1.22s
# 431:	learn: 0.2175926	total: 14.6s	remaining: 1.19s
# 432:	learn: 0.2175720	total: 14.7s	remaining: 1.15s
# 433:	learn: 0.2175453	total: 14.7s	remaining: 1.12s
# 434:	learn: 0.2175021	total: 14.7s	remaining: 1.08s
# 435:	learn: 0.2174741	total: 14.8s	remaining: 1.05s
# 436:	learn: 0.2174464	total: 14.8s	remaining: 1.01s
# 437:	learn: 0.2173578	total: 14.8s	remaining: 983ms
# 438:	learn: 0.2173036	total: 14.9s	remaining: 949ms
# 439:	learn: 0.2172781	total: 14.9s	remaining: 915ms
# 440:	learn: 0.2172439	total: 15s	remaining: 882ms
# 441:	learn: 0.2172162	total: 15s	remaining: 848ms
# 442:	learn: 0.2171869	total: 15s	remaining: 814ms
# 443:	learn: 0.2171574	total: 15.1s	remaining: 780ms
# 444:	learn: 0.2171343	total: 15.1s	remaining: 746ms
# 445:	learn: 0.2171070	total: 15.1s	remaining: 712ms
# 446:	learn: 0.2170796	total: 15.2s	remaining: 678ms
# 447:	learn: 0.2169857	total: 15.2s	remaining: 644ms
# 448:	learn: 0.2169549	total: 15.2s	remaining: 610ms
# 449:	learn: 0.2169304	total: 15.3s	remaining: 576ms
# 450:	learn: 0.2168981	total: 15.3s	remaining: 542ms
# 451:	learn: 0.2168765	total: 15.3s	remaining: 508ms
# 452:	learn: 0.2168465	total: 15.3s	remaining: 474ms
# 453:	learn: 0.2168165	total: 15.4s	remaining: 440ms
# 454:	learn: 0.2167191	total: 15.4s	remaining: 406ms
# 455:	learn: 0.2166968	total: 15.4s	remaining: 372ms
# 456:	learn: 0.2166792	total: 15.4s	remaining: 338ms
# 457:	learn: 0.2166521	total: 15.5s	remaining: 304ms
# 458:	learn: 0.2166268	total: 15.5s	remaining: 270ms
# 459:	learn: 0.2165923	total: 15.5s	remaining: 237ms
# 460:	learn: 0.2165624	total: 15.6s	remaining: 203ms
# 461:	learn: 0.2165305	total: 15.6s	remaining: 169ms
# 462:	learn: 0.2164995	total: 15.6s	remaining: 135ms
# 463:	learn: 0.2164781	total: 15.7s	remaining: 101ms
# 464:	learn: 0.2164558	total: 15.7s	remaining: 67.4ms
# 465:	learn: 0.2164245	total: 15.7s	remaining: 33.7ms
# 466:	learn: 0.2163986	total: 15.7s	remaining: 0us

# %% [markdown]
# # Evaluate

# %%
models = [model_xgb, model_cb]
accu_rates = []

for model in models:
    accu_rates.append(evaluate(model))

# Train: 0.8874	Dev: 0.8831
# Train: 0.9154	Dev: 0.9084
# Out:
# Train: 0.8874	Dev: 0.8831
# Train: 0.912	Dev: 0.9082

# %%
best_model = models[np.argmax(accu_rates)]

# %% [markdown]
# # Submit

# %%
x_test = test.drop(drop_cols_test, axis=1)
x_test = scaler.transform(x_test)

test_pred = best_model.predict(x_test)
[test_pred] = test_pred.reshape(1, len(test_pred))
output = pd.DataFrame({'id': test.id, 'Exited': test_pred})
output.to_csv('submission.csv', index=False)
