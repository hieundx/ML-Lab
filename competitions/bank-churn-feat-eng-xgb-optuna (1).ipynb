# %% [markdown]
# # Load data

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score

data = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')

data.head()
# Out:
#    id  CustomerId         Surname  CreditScore Geography Gender   Age  Tenure  \
# 0   0    15674932  Okwudilichukwu          668    France   Male  33.0       3
# 1   1    15749177   Okwudiliolisa          627    France   Male  33.0       1
# 2   2    15694510           Hsueh          678    France   Male  40.0      10
# 3   3    15741417             Kao          581    France   Male  34.0       2
# 4   4    15766172       Chiemenam          716     Spain   Male  33.0       5
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              2        1.0             0.0        181449.97
# 1       0.00              2        1.0             1.0         49503.50
# 2       0.00              2        1.0             0.0        184866.69
# 3  148882.54              1        1.0             1.0         84560.88
# 4       0.00              2        1.0             1.0         15068.83
#
#    Exited
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
print('Training size: ', data.shape[0])
# Out:
# Training size:  165034

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## Determine ranges

# %%
print(data['Age'].describe(), end='\n\n')
print(data['EstimatedSalary'].describe(), end='\n\n')
# Out:
# count    165034.000000
# mean         38.125888
# std           8.867205
# min          18.000000
# 25%          32.000000
# 50%          37.000000
# 75%          42.000000
# max          92.000000
# Name: Age, dtype: float64
#
# count    165034.000000
# mean     112574.822734
# std       50292.865585
# min          11.580000
# 25%       74637.570000
# 50%      117948.000000
# 75%      155152.467500
# max      199992.480000
# Name: EstimatedSalary, dtype: float64

# %% [markdown]
# We can see that salary ranges from 11.58 (almost 0) to 199,992.48 (around 200k). First and third quartiles are near multiples of 50k, with median over twice of 50k. So it makes sense to stratefy this column into 0 - 50k, 50k - 100k, 100k - 200k ranges.

# %% [markdown]
# ## Binning

# %%
def cut(data, col, bins):
    preview = pd.cut(data[col], bins=bins)
    print('*** PREVIEW with LABELS ***')
    print(preview.value_counts())
    
    data[f'{col}Group'] = pd.cut(data[col], bins=bins, labels=False)
    print(f'{col}Group (no labels) created')
    print()

# %% [markdown]
# ## Feature engineering

# %%
def engineer(data):
    # Age groups
    cut(data, 'Age', 5)
    
    # https://www.experian.com/blogs/ask-experian/infographic-what-are-the-different-scoring-ranges/
    cut(data, 'CreditScore', [0, 300, 580, 670, 740, 800, np.inf])
    
    cut(data, 'EstimatedSalary', [0, 50000, 100000, np.inf])
    
    data['BalanceToSalaryRatio'] = data['Balance'] / data['EstimatedSalary']
    print(data['BalanceToSalaryRatio'].describe())
    print()
    
    data['TenureGroup'] = pd.cut(data['Tenure'], bins=[0, 2, 5, 10, np.inf], labels=False)
    
    data['CreditCard_ActiveMember'] = data['HasCrCard'] * data['IsActiveMember']
    
    return data

# %% [markdown]
# ## Remove outliers
# Outliers can make our model more biased towards such samples. Removing them might increase accuracy on test data.

# %%
def remove_outliers(df):
    quant_cols = [
        'CreditScore',
        'Age', 
        'Balance', 
        'EstimatedSalary'
    ]
    
    for col in quant_cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3-Q1

        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        
        df = df[(df[col] >= lower) & (df[col] <= upper)]
    return df

# %% [markdown]
# ## Label Encoding

# %%
class SurnameEncoder:
    def __init__(self, train_set, test_set):
        self.le = LabelEncoder()
        self.le.fit(pd.concat([train_set, test])['Surname'])
    
    def transform(self, df):
        df['Surname'] = self.le.transform(df['Surname'])
        return df

# %% [markdown]
# ## Combined data processing

# %%
se = SurnameEncoder(data, test)

data = remove_outliers(data)
data = engineer(data)
data = se.transform(data)

test = engineer(test)
test = se.transform(test)
# Out:
# *** PREVIEW with LABELS ***
# Age
# (33.6, 41.4]      67043
# (25.8, 33.6]      44887
# (41.4, 49.2]      28876
# (49.2, 57.0]      10510
# (17.961, 25.8]     7084
# Name: count, dtype: int64
# AgeGroup (no labels) created
#
# *** PREVIEW with LABELS ***
# CreditScore
# (580.0, 670.0]    59741
# (670.0, 740.0]    50004
# (300.0, 580.0]    26758
# (740.0, 800.0]    15591
# (800.0, inf]       6306
# (0.0, 300.0]          0
# Name: count, dtype: int64
# CreditScoreGroup (no labels) created
#
# *** PREVIEW with LABELS ***
# EstimatedSalary
# (100000.0, inf]        94558
# (50000.0, 100000.0]    44869
# (0.0, 50000.0]         18973
# Name: count, dtype: int64
# EstimatedSalaryGroup (no labels) created
#
# count    158400.000000
# mean          2.111896
# std          93.404463
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.973252
# max       12863.796200
# Name: BalanceToSalaryRatio, dtype: float64
#
# *** PREVIEW with LABELS ***
# Age
# (32.8, 47.6]      66677
# (17.926, 32.8]    29148
# (47.6, 62.4]      12294
# (62.4, 77.2]       1829
# (77.2, 92.0]         75
# Name: count, dtype: int64
# AgeGroup (no labels) created
#
# *** PREVIEW with LABELS ***
# CreditScore
# (580.0, 670.0]    41333
# (670.0, 740.0]    34596
# (300.0, 580.0]    18723
# (740.0, 800.0]    10923
# (800.0, inf]       4448
# (0.0, 300.0]          0
# Name: count, dtype: int64
# CreditScoreGroup (no labels) created
#
# *** PREVIEW with LABELS ***
# EstimatedSalary
# (100000.0, inf]        65148
# (50000.0, 100000.0]    31290
# (0.0, 50000.0]         13585
# Name: count, dtype: int64
# EstimatedSalaryGroup (no labels) created
#
# count    110023.000000
# mean          2.115039
# std          86.120211
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.978741
# max       10614.655440
# Name: BalanceToSalaryRatio, dtype: float64

# %% [markdown]
# # Split training data

# %%
drop_cols_test = ['id', 'CustomerId']
drop_cols = ['id', 'CustomerId', 'Exited']
x_data = pd.get_dummies(data.drop(columns=drop_cols)).astype(np.float32)
y_data = (data['Exited']).astype(np.float32)

scaler = StandardScaler()
x_data = scaler.fit_transform(x_data)

# Large data set therefore we just need a small test size for validation purpose
x_train, x_, y_train, y_ = train_test_split(x_data, y_data, test_size=0.2, random_state=0)

# %%
def predict(model, x, y):
    p = model.predict(x)
    p = p.reshape(1, len(p))[0]
    p = np.array(list(map(lambda p: 1 if p >= 0.5 else 0, p)))

    accu = round(accuracy_score(p,  y) , 4)
    
    return accu

def evaluate(model):
    accu_train = predict(model, x_train, y_train)
    accu_dev = predict(model, x_, y_)
    
    print(f'Train: {accu_train}\tDev: {accu_dev}')

    return accu_dev

# %% [markdown]
# # Hyper parameter tuning

# %% [markdown]
# Run this code separately.

# %%
from sklearn.model_selection import  cross_val_score
from sklearn.model_selection import StratifiedKFold
import optuna
from xgboost import XGBRegressor

# Assuming 'skf' is your StratifiedKFold object
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

def objective_xgb(trial):
    """Define the objective function for XGBClassifier"""

    params = {
        'max_depth': trial.suggest_int('max_depth', 5, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 1.0),
        'n_estimators': trial.suggest_int('n_estimators', 150, 1000),
        'subsample': trial.suggest_float('subsample', 0.01, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.01, 1.0),
        'random_state': trial.suggest_categorical('random_state', [42]),
        'tree_method': 'hist',  # Use GPU for training
        'device' : 'cuda',
        'eval_metric': 'auc',  # Evaluation metric
        'verbosity': 2,  # Set verbosity to 0 for less output
    }

    xgb_model = XGBRegressor(**params)

    cv = abs(cross_val_score(xgb_model, x_train, y_train, cv=skf, scoring='roc_auc').mean())

    return cv

study = optuna.create_study(direction='maximize')
study.optimize(objective_xgb, n_trials=50)

# Get the best parameters
best_params_xgb = study.best_params
print("Best Hyperparameters for XGBoost:", best_params_xgb)
# Out:
# [I 2024-01-14 15:31:13,624] A new study created in memory with name: no-name-ad1a83e2-aa6e-4c4e-83a5-02bd0f95bc4b
# [I 2024-01-14 15:31:23,472] Trial 0 finished with value: 0.8383001448444226 and parameters: {'max_depth': 5, 'min_child_weight': 4, 'learning_rate': 0.9747891959400499, 'n_estimators': 258, 'subsample': 0.6520768269723052, 'colsample_bytree': 0.802880629092744, 'random_state': 42}. Best is trial 0 with value: 0.8383001448444226.
# [I 2024-01-14 15:31:36,774] Trial 1 finished with value: 0.8230423303656433 and parameters: {'max_depth': 8, 'min_child_weight': 10, 'learning_rate': 0.7158424645307248, 'n_estimators': 189, 'subsample': 0.8444203465265168, 'colsample_bytree': 0.6169176395534726, 'random_state': 42}. Best is trial 0 with value: 0.8383001448444226.
# [I 2024-01-14 15:32:02,248] Trial 2 finished with value: 0.8604539297754205 and parameters: {'max_depth': 5, 'min_child_weight': 4, 'learning_rate': 0.32580211834388895, 'n_estimators': 816, 'subsample': 0.5270860253887788, 'colsample_bytree': 0.717373718082386, 'random_state': 42}. Best is trial 2 with value: 0.8604539297754205.
# [I 2024-01-14 15:32:33,550] Trial 3 finished with value: 0.8833730121395404 and parameters: {'max_depth': 8, 'min_child_weight': 9, 'learning_rate': 0.07597804038309304, 'n_estimators': 776, 'subsample': 0.26346023194137863, 'colsample_bytree': 0.1467471257508993, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:32:50,763] Trial 4 finished with value: 0.8580825002801236 and parameters: {'max_depth': 6, 'min_child_weight': 1, 'learning_rate': 0.9274067210415521, 'n_estimators': 546, 'subsample': 0.7309827033917348, 'colsample_bytree': 0.11515673015889338, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:33:35,951] Trial 5 finished with value: 0.8265733905940754 and parameters: {'max_depth': 8, 'min_child_weight': 9, 'learning_rate': 0.39363649389024563, 'n_estimators': 714, 'subsample': 0.7616719924434783, 'colsample_bytree': 0.7249252929949502, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:33:56,791] Trial 6 finished with value: 0.7627909206389611 and parameters: {'max_depth': 6, 'min_child_weight': 9, 'learning_rate': 0.8600998037647222, 'n_estimators': 576, 'subsample': 0.2763943848452195, 'colsample_bytree': 0.2513822318450554, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:34:16,639] Trial 7 finished with value: 0.7621422456509762 and parameters: {'max_depth': 9, 'min_child_weight': 1, 'learning_rate': 0.7468521603834398, 'n_estimators': 200, 'subsample': 0.4880709156184796, 'colsample_bytree': 0.4068684662569144, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:35:04,804] Trial 8 finished with value: 0.7307432664770019 and parameters: {'max_depth': 9, 'min_child_weight': 5, 'learning_rate': 0.8649423490163936, 'n_estimators': 508, 'subsample': 0.5886386567143487, 'colsample_bytree': 0.8383220021285025, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:35:51,184] Trial 9 finished with value: 0.6139792255439934 and parameters: {'max_depth': 10, 'min_child_weight': 6, 'learning_rate': 0.28927956756257445, 'n_estimators': 690, 'subsample': 0.026641467143057963, 'colsample_bytree': 0.2694199810037361, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:36:14,848] Trial 10 finished with value: 0.8746196365165039 and parameters: {'max_depth': 7, 'min_child_weight': 7, 'learning_rate': 0.022575026597350223, 'n_estimators': 918, 'subsample': 0.2388826780723683, 'colsample_bytree': 0.04678887687427041, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:36:39,779] Trial 11 finished with value: 0.8779296506445406 and parameters: {'max_depth': 7, 'min_child_weight': 7, 'learning_rate': 0.030734005059244264, 'n_estimators': 966, 'subsample': 0.26589813244232774, 'colsample_bytree': 0.028593224562137365, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:37:05,332] Trial 12 finished with value: 0.880623136577988 and parameters: {'max_depth': 7, 'min_child_weight': 8, 'learning_rate': 0.06896903418379854, 'n_estimators': 999, 'subsample': 0.24562965693385416, 'colsample_bytree': 0.01265394604753485, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:37:48,802] Trial 13 finished with value: 0.8095228875144999 and parameters: {'max_depth': 8, 'min_child_weight': 8, 'learning_rate': 0.19900542156779633, 'n_estimators': 838, 'subsample': 0.08285118367560546, 'colsample_bytree': 0.2658518234942722, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:38:33,460] Trial 14 finished with value: 0.8524018928166278 and parameters: {'max_depth': 7, 'min_child_weight': 10, 'learning_rate': 0.15309809266076643, 'n_estimators': 962, 'subsample': 0.38476857067872244, 'colsample_bytree': 0.9822471623677296, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:39:39,167] Trial 15 finished with value: 0.8172865088830147 and parameters: {'max_depth': 9, 'min_child_weight': 8, 'learning_rate': 0.5507675420676165, 'n_estimators': 798, 'subsample': 0.9881674734474453, 'colsample_bytree': 0.47289812420825583, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:39:53,501] Trial 16 finished with value: 0.8317530397021592 and parameters: {'max_depth': 6, 'min_child_weight': 8, 'learning_rate': 0.5042454178786268, 'n_estimators': 405, 'subsample': 0.13933937655845072, 'colsample_bytree': 0.1899498152797856, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:41:12,473] Trial 17 finished with value: 0.8375727747964937 and parameters: {'max_depth': 10, 'min_child_weight': 6, 'learning_rate': 0.17250583071914635, 'n_estimators': 686, 'subsample': 0.40653822697362674, 'colsample_bytree': 0.3772183762171909, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:41:53,680] Trial 18 finished with value: 0.8767891357103036 and parameters: {'max_depth': 8, 'min_child_weight': 9, 'learning_rate': 0.08851422273250892, 'n_estimators': 885, 'subsample': 0.17556506108878292, 'colsample_bytree': 0.1663200996713715, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:42:12,870] Trial 19 finished with value: 0.8795776386437602 and parameters: {'max_depth': 7, 'min_child_weight': 7, 'learning_rate': 0.26239169365777, 'n_estimators': 744, 'subsample': 0.3578871121927701, 'colsample_bytree': 0.02599304389765253, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:43:26,673] Trial 20 finished with value: 0.7572048512554218 and parameters: {'max_depth': 9, 'min_child_weight': 10, 'learning_rate': 0.4659231610576301, 'n_estimators': 983, 'subsample': 0.3274850182685768, 'colsample_bytree': 0.3303411208938697, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:43:46,167] Trial 21 finished with value: 0.8799320548898211 and parameters: {'max_depth': 7, 'min_child_weight': 7, 'learning_rate': 0.2653871399573199, 'n_estimators': 759, 'subsample': 0.44241658545407814, 'colsample_bytree': 0.09462503637160116, 'random_state': 42}. Best is trial 3 with value: 0.8833730121395404.
# [I 2024-01-14 15:44:05,282] Trial 22 finished with value: 0.8851958465570646 and parameters: {'max_depth': 6, 'min_child_weight': 8, 'learning_rate': 0.11382478718705116, 'n_estimators': 614, 'subsample': 0.47718355474158536, 'colsample_bytree': 0.13421194622605517, 'random_state': 42}. Best is trial 22 with value: 0.8851958465570646.
# [I 2024-01-14 15:44:26,346] Trial 23 finished with value: 0.8776857863187454 and parameters: {'max_depth': 6, 'min_child_weight': 9, 'learning_rate': 0.12504986059717602, 'n_estimators': 615, 'subsample': 0.12374714869608996, 'colsample_bytree': 0.16120488097011154, 'random_state': 42}. Best is trial 22 with value: 0.8851958465570646.
# [I 2024-01-14 15:44:39,861] Trial 24 finished with value: 0.8898610215997781 and parameters: {'max_depth': 5, 'min_child_weight': 8, 'learning_rate': 0.013548185176720198, 'n_estimators': 430, 'subsample': 0.21698876741722295, 'colsample_bytree': 0.5751804413817208, 'random_state': 42}. Best is trial 24 with value: 0.8898610215997781.
# [I 2024-01-14 15:44:53,276] Trial 25 finished with value: 0.88191426216675 and parameters: {'max_depth': 5, 'min_child_weight': 5, 'learning_rate': 0.19182863460564098, 'n_estimators': 435, 'subsample': 0.5534704552391656, 'colsample_bytree': 0.5527795289980173, 'random_state': 42}. Best is trial 24 with value: 0.8898610215997781.
# [I 2024-01-14 15:45:04,764] Trial 26 finished with value: 0.8898671816136767 and parameters: {'max_depth': 5, 'min_child_weight': 3, 'learning_rate': 0.019718954841041365, 'n_estimators': 363, 'subsample': 0.18852330162094694, 'colsample_bytree': 0.5311793296868652, 'random_state': 42}. Best is trial 26 with value: 0.8898671816136767.
# [I 2024-01-14 15:45:16,246] Trial 27 finished with value: 0.8876775607902048 and parameters: {'max_depth': 5, 'min_child_weight': 2, 'learning_rate': 0.011121616580224451, 'n_estimators': 359, 'subsample': 0.03333880945416523, 'colsample_bytree': 0.581908156916549, 'random_state': 42}. Best is trial 26 with value: 0.8898671816136767.
# [I 2024-01-14 15:45:26,184] Trial 28 finished with value: 0.8871277908363677 and parameters: {'max_depth': 5, 'min_child_weight': 2, 'learning_rate': 0.032893050453172035, 'n_estimators': 312, 'subsample': 0.04863357308953942, 'colsample_bytree': 0.5963672533699813, 'random_state': 42}. Best is trial 26 with value: 0.8898671816136767.
# [I 2024-01-14 15:45:36,699] Trial 29 finished with value: 0.5567307726157862 and parameters: {'max_depth': 5, 'min_child_weight': 3, 'learning_rate': 0.610485715439506, 'n_estimators': 340, 'subsample': 0.01779462578589818, 'colsample_bytree': 0.49311458000135033, 'random_state': 42}. Best is trial 26 with value: 0.8898671816136767.
# [I 2024-01-14 15:45:45,576] Trial 30 finished with value: 0.8541742364270585 and parameters: {'max_depth': 5, 'min_child_weight': 3, 'learning_rate': 0.3713496989760826, 'n_estimators': 274, 'subsample': 0.18772244099595253, 'colsample_bytree': 0.6699904809546834, 'random_state': 42}. Best is trial 26 with value: 0.8898671816136767.
# [I 2024-01-14 15:45:56,179] Trial 31 finished with value: 0.8885363274048185 and parameters: {'max_depth': 5, 'min_child_weight': 2, 'learning_rate': 0.011912672246714903, 'n_estimators': 325, 'subsample': 0.095891053246277, 'colsample_bytree': 0.5866955165770007, 'random_state': 42}. Best is trial 26 with value: 0.8898671816136767.
# [I 2024-01-14 15:46:08,654] Trial 32 finished with value: 0.8888926763916478 and parameters: {'max_depth': 5, 'min_child_weight': 2, 'learning_rate': 0.01616932161278853, 'n_estimators': 396, 'subsample': 0.08339993212956923, 'colsample_bytree': 0.5603050699982961, 'random_state': 42}. Best is trial 26 with value: 0.8898671816136767.
# [I 2024-01-14 15:46:22,513] Trial 33 finished with value: 0.8579014648508313 and parameters: {'max_depth': 5, 'min_child_weight': 3, 'learning_rate': 0.19936588903460026, 'n_estimators': 447, 'subsample': 0.10287185339641283, 'colsample_bytree': 0.6570077843563371, 'random_state': 42}. Best is trial 26 with value: 0.8898671816136767.
# [I 2024-01-14 15:46:28,132] Trial 34 finished with value: 0.8883160802533945 and parameters: {'max_depth': 5, 'min_child_weight': 2, 'learning_rate': 0.0900290330378975, 'n_estimators': 155, 'subsample': 0.1884459041898864, 'colsample_bytree': 0.4487494681831203, 'random_state': 42}. Best is trial 26 with value: 0.8898671816136767.
# [I 2024-01-14 15:46:45,780] Trial 35 finished with value: 0.8605506576509377 and parameters: {'max_depth': 6, 'min_child_weight': 1, 'learning_rate': 0.23529466451908287, 'n_estimators': 471, 'subsample': 0.31397037519786075, 'colsample_bytree': 0.5327484435722826, 'random_state': 42}. Best is trial 26 with value: 0.8898671816136767.
# [I 2024-01-14 15:46:57,578] Trial 36 finished with value: 0.8755482230665457 and parameters: {'max_depth': 5, 'min_child_weight': 4, 'learning_rate': 0.14498732767146905, 'n_estimators': 379, 'subsample': 0.15074633546315114, 'colsample_bytree': 0.7689536824109986, 'random_state': 42}. Best is trial 26 with value: 0.8898671816136767.
# [I 2024-01-14 15:47:08,566] Trial 37 finished with value: 0.8858582093847689 and parameters: {'max_depth': 6, 'min_child_weight': 4, 'learning_rate': 0.07898453665870808, 'n_estimators': 279, 'subsample': 0.20934184227026173, 'colsample_bytree': 0.6425269007534333, 'random_state': 42}. Best is trial 26 with value: 0.8898671816136767.
# [I 2024-01-14 15:47:16,240] Trial 38 finished with value: 0.84063914264457 and parameters: {'max_depth': 5, 'min_child_weight': 2, 'learning_rate': 0.33651658305497517, 'n_estimators': 230, 'subsample': 0.0870216184708138, 'colsample_bytree': 0.8532984340939282, 'random_state': 42}. Best is trial 26 with value: 0.8898671816136767.
# [I 2024-01-14 15:47:35,948] Trial 39 finished with value: 0.8909481388490903 and parameters: {'max_depth': 6, 'min_child_weight': 3, 'learning_rate': 0.011514316949476584, 'n_estimators': 520, 'subsample': 0.3005629662407421, 'colsample_bytree': 0.7104732253814815, 'random_state': 42}. Best is trial 39 with value: 0.8909481388490903.
# [I 2024-01-14 15:47:55,410] Trial 40 finished with value: 0.7806823939244196 and parameters: {'max_depth': 6, 'min_child_weight': 3, 'learning_rate': 0.6819668686331376, 'n_estimators': 523, 'subsample': 0.31203629692956913, 'colsample_bytree': 0.7180046739625573, 'random_state': 42}. Best is trial 39 with value: 0.8909481388490903.
# [I 2024-01-14 15:48:08,149] Trial 41 finished with value: 0.8851838178354958 and parameters: {'max_depth': 5, 'min_child_weight': 1, 'learning_rate': 0.05973506035710078, 'n_estimators': 412, 'subsample': 0.08343666322039803, 'colsample_bytree': 0.5260812122426548, 'random_state': 42}. Best is trial 39 with value: 0.8909481388490903.
# [I 2024-01-14 15:48:22,598] Trial 42 finished with value: 0.8904638048609657 and parameters: {'max_depth': 5, 'min_child_weight': 3, 'learning_rate': 0.021778463441410902, 'n_estimators': 466, 'subsample': 0.21542483471583623, 'colsample_bytree': 0.775025405994419, 'random_state': 42}. Best is trial 39 with value: 0.8909481388490903.
# [I 2024-01-14 15:48:41,069] Trial 43 finished with value: 0.8749335108991454 and parameters: {'max_depth': 6, 'min_child_weight': 5, 'learning_rate': 0.11583178630912047, 'n_estimators': 473, 'subsample': 0.21237229937345453, 'colsample_bytree': 0.7812239484693522, 'random_state': 42}. Best is trial 39 with value: 0.8909481388490903.
# [I 2024-01-14 15:48:58,416] Trial 44 finished with value: 0.8880719317509265 and parameters: {'max_depth': 5, 'min_child_weight': 3, 'learning_rate': 0.06263138409174981, 'n_estimators': 565, 'subsample': 0.2960636386214868, 'colsample_bytree': 0.8452133707136666, 'random_state': 42}. Best is trial 39 with value: 0.8909481388490903.
# [I 2024-01-14 15:49:17,598] Trial 45 finished with value: 0.8909069947466021 and parameters: {'max_depth': 6, 'min_child_weight': 4, 'learning_rate': 0.012850817190767156, 'n_estimators': 507, 'subsample': 0.23342946219948305, 'colsample_bytree': 0.9026291838561974, 'random_state': 42}. Best is trial 39 with value: 0.8909481388490903.
# [I 2024-01-14 15:49:37,449] Trial 46 finished with value: 0.8736491279278953 and parameters: {'max_depth': 6, 'min_child_weight': 4, 'learning_rate': 0.13048249716979654, 'n_estimators': 504, 'subsample': 0.2501106206026735, 'colsample_bytree': 0.9296714793503651, 'random_state': 42}. Best is trial 39 with value: 0.8909481388490903.
# [I 2024-01-14 15:49:59,485] Trial 47 finished with value: 0.8591628164903259 and parameters: {'max_depth': 6, 'min_child_weight': 4, 'learning_rate': 0.21964806350858104, 'n_estimators': 594, 'subsample': 0.3614985219157941, 'colsample_bytree': 0.910659843671017, 'random_state': 42}. Best is trial 39 with value: 0.8909481388490903.
# [I 2024-01-14 15:50:23,319] Trial 48 finished with value: 0.7760202820979487 and parameters: {'max_depth': 6, 'min_child_weight': 4, 'learning_rate': 0.9705873655309479, 'n_estimators': 642, 'subsample': 0.6116097998043839, 'colsample_bytree': 0.7455662141801638, 'random_state': 42}. Best is trial 39 with value: 0.8909481388490903.
# [I 2024-01-14 15:50:42,957] Trial 49 finished with value: 0.8879037294341927 and parameters: {'max_depth': 6, 'min_child_weight': 6, 'learning_rate': 0.07343739576797166, 'n_estimators': 537, 'subsample': 0.7498059846489155, 'colsample_bytree': 0.6941710000266058, 'random_state': 42}. Best is trial 39 with value: 0.8909481388490903.
# Best Hyperparameters for XGBoost: {'max_depth': 6, 'min_child_weight': 3, 'learning_rate': 0.011514316949476584, 'n_estimators': 520, 'subsample': 0.3005629662407421, 'colsample_bytree': 0.7104732253814815, 'random_state': 42}

# %% [markdown]
# Best Hyperparameters found using Optuna
# ```
# {
#     'max_depth': 6,
#     'min_child_weight': 3,
#     'learning_rate': 0.011514316949476584,
#     'n_estimators': 520,
#     'subsample': 0.3005629662407421,
#     'colsample_bytree': 0.7104732253814815,
#     'random_state': 42
# }
# ```

# %% [markdown]
# # Train

# %%
from xgboost import XGBRegressor

params = {
    'max_depth': 6, 
    'min_child_weight': 3, 
    'learning_rate': 0.011514316949476584, 
    'n_estimators': 520, 
    'subsample': 0.3005629662407421, 
    'colsample_bytree': 0.7104732253814815, 
    'random_state': 42
}

# Params found using Optuna
model_xgb = XGBRegressor(**params)
model_xgb.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7104732253814815, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.011514316949476584, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=3, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=520, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# # Evaluate

# %%
models = [model_xgb]
accu_rates = []

for model in models:
    accu_rates.append(evaluate(model))
# Out:
# Train: 0.8722	Dev: 0.8664

# %%
best_model = models[np.argmax(accu_rates)]

# %% [markdown]
# # Submit

# %%
x_test = pd.get_dummies(test.drop(columns=drop_cols_test)).astype('float32')

x_test = scaler.transform(x_test)

test_pred = best_model.predict(x_test)
[test_pred] = test_pred.reshape(1, len(test_pred))
output = pd.DataFrame({'id': test.id, 'Exited': test_pred})
output.to_csv('submission.csv', index=False)
